# %%
from requests import Request,Session 
from requests.exceptions import ConnectionError , Timeout , TooManyRedirects 

import os 
from time import time 
from time import sleep

import json 
import pandas as pd 


pd.set_option('display.max_columns' , None)
pd.set_option('display.max_rows' , None)

# %%
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
#This allows you to see all the columns, not just like 15
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#This normalizes the data and makes it all pretty in a dataframe

df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now' , utc = True)
df.head()
# Out:
#      id         name symbol      slug  num_market_pairs  \
# 0     1      Bitcoin    BTC   bitcoin             10386
# 1  1027     Ethereum    ETH  ethereum              7225
# 2   825  Tether USDt   USDT    tether             59272
# 3  1839          BNB    BNB       bnb              1562
# 4    52          XRP    XRP       xrp              1026
#
#                  date_added  \
# 0  2010-07-13T00:00:00.000Z
# 1  2015-08-07T00:00:00.000Z
# 2  2015-02-25T00:00:00.000Z
# 3  2017-07-25T00:00:00.000Z
# 4  2013-08-04T00:00:00.000Z
#
#                                                 tags    max_supply  \
# 0  [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1  [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2  [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3  [marketplace, centralized-exchange, payments, ...           NaN
# 4  [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
#
#    circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0        1.945380e+07  1.945380e+07            False       NaN         1
# 1        1.201497e+08  1.201497e+08             True       NaN         2
# 2        8.353343e+10  8.668426e+10             True       NaN         3
# 3        1.538533e+08  1.538533e+08            False       NaN         4
# 4        5.278728e+10  9.998852e+10            False       NaN         5
#
#    self_reported_circulating_supply  self_reported_market_cap tvl_ratio  \
# 0                               NaN                       NaN      None
# 1                               NaN                       NaN      None
# 2                               NaN                       NaN      None
# 3                               NaN                       NaN      None
# 4                               NaN                       NaN      None
#
#                last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0  2023-08-11T05:28:00.000Z     29364.933628          1.158347e+10
# 1  2023-08-11T05:28:00.000Z      1845.844109          3.768608e+09
# 2  2023-08-11T05:28:00.000Z         0.998601          1.825064e+10
# 3  2023-08-11T05:28:00.000Z       240.295859          3.808042e+08
# 4  2023-08-11T05:28:00.000Z         0.636385          1.108262e+09
#
#    quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                     -34.7103                    -0.062749
# 1                     -32.1227                     0.027352
# 2                     -17.7671                    -0.004235
# 3                       0.9895                    -0.078493
# 4                     -33.8136                    -0.352236
#
#    quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                     -0.417093                     0.622025
# 1                     -0.189063                     0.658998
# 2                     -0.046479                    -0.038274
# 3                     -1.113861                    -0.666656
# 4                      0.065591                    -4.278737
#
#    quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                     -4.132124                     13.781506
# 1                     -1.986692                      6.097030
# 2                     -0.160463                     -0.153855
# 3                     -3.690492                      6.048751
# 4                     33.823033                     23.298865
#
#    quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                      9.349270          5.712595e+11
# 1                      2.228499          2.217776e+11
# 2                     -0.166555          8.341655e+10
# 3                    -22.609537          3.697031e+10
# 4                     48.748703          3.359303e+10
#
#    quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                         48.7424                        6.166636e+11
# 1                         18.9231                        2.217776e+11
# 2                          7.1175                        8.656297e+10
# 3                          3.1545                        3.697031e+10
# 4                          2.8664                        6.363849e+10
#
#   quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0          None  2023-08-11T05:28:00.000Z          NaN           NaN
# 1          None  2023-08-11T05:28:00.000Z          NaN           NaN
# 2          None  2023-08-11T05:28:00.000Z       1027.0      Ethereum
# 3          None  2023-08-11T05:28:00.000Z          NaN           NaN
# 4          None  2023-08-11T05:28:00.000Z          NaN           NaN
#
#   platform.symbol platform.slug                      platform.token_address  \
# 0             NaN           NaN                                         NaN
# 1             NaN           NaN                                         NaN
# 2             ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3             NaN           NaN                                         NaN
# 4             NaN           NaN                                         NaN
#
#                          timestamp
# 0 2023-08-11 05:30:09.510560+00:00
# 1 2023-08-11 05:30:09.510560+00:00
# 2 2023-08-11 05:30:09.510560+00:00
# 3 2023-08-11 05:30:09.510560+00:00
# 4 2023-08-11 05:30:09.510560+00:00

# %%
df = pd.DataFrame()  # Initialize an empty DataFrame

def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start': '1',
      'limit': '15',
      'convert': 'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)

    df2 = pd.json_normalize(data['data'])
    df2['Timestamp'] = pd.to_datetime('now', utc=True)
    df = pd.concat([df, df2])  # Concatenate the new data to the existing DataFrame

    directory = r"D:\Webscrappers\CoinMarketCapital\Dataset"
    if not os.path.exists(directory):
        os.makedirs(directory)

    csv_path = os.path.join(directory, 'API.csv')
    if not os.path.isfile(csv_path):
        df.to_csv(csv_path, header='column_names')
    else:
        df.to_csv(csv_path, mode='a', header=False, index=False)

for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(60)  # Sleep for 1 minute

exit()
# Out:
# API Runner completed
